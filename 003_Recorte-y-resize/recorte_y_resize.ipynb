# %%
# !pip install scikit-image watermark -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.6 MB/s eta 0:00:00

# %%
import numpy as np
#numpy es para matrices
import cv2
from cv2 import imread
#cv2 es para vision por computador y procesamiento de imagenes
import matplotlib.pyplot as plt

# %%
# !wget https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/140075.jpg
# Out:
# --2025-04-21 17:25:26--  https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/normal/color/140075.jpg
# Resolving www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)... 128.32.244.190
# Connecting to www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)|128.32.244.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33618 (33K) [image/jpeg]
# Saving to: ‘140075.jpg’
#
# 140075.jpg          100%[===================>]  32.83K  --.-KB/s    in 0.05s
#
# 2025-04-21 17:25:26 (665 KB/s) - ‘140075.jpg’ saved [33618/33618]

# %%
img2= imread('140075.jpg')
plt.imshow(img2)
plt.show()

# %%
img2.shape
# Out:
# (321, 481, 3)

# %%
img_cropped=img2[230:321, 340:481]
plt.imshow(img_cropped)

# %%
plt.figure(figsize=(3, 3))  # Cambio los valores para mejorar la resolucion
plt.imshow(img_cropped)
plt.axis('off')
plt.show()

# %%
img_rgb2=cv2.cvtColor(img_cropped, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb2)
plt.show()

# %%
# !wget https://www.cevagraf.coop/blog/wp-content/uploads/2019/12/Imagenes-HD-en-alta-resolucion-para-imprimir-1250x656.jpg
# Out:
# --2025-04-21 17:40:54--  https://www.cevagraf.coop/blog/wp-content/uploads/2019/12/Imagenes-HD-en-alta-resolucion-para-imprimir-1250x656.jpg
# Resolving www.cevagraf.coop (www.cevagraf.coop)... 46.226.45.27
# Connecting to www.cevagraf.coop (www.cevagraf.coop)|46.226.45.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62937 (61K) [image/jpeg]
# Saving to: ‘Imagenes-HD-en-alta-resolucion-para-imprimir-1250x656.jpg’
#
# Imagenes-HD-en-alta 100%[===================>]  61.46K   294KB/s    in 0.2s
#
# 2025-04-21 17:40:55 (294 KB/s) - ‘Imagenes-HD-en-alta-resolucion-para-imprimir-1250x656.jpg’ saved [62937/62937]

# %%
# !wget https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/quarter/color/241048.jpg
# Out:
# --2025-04-21 17:25:27--  https://www2.eecs.berkeley.edu/Research/Projects/CS/vision/bsds/BSDS300/html/images/plain/quarter/color/241048.jpg
# Resolving www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)... 128.32.244.190
# Connecting to www2.eecs.berkeley.edu (www2.eecs.berkeley.edu)|128.32.244.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3299 (3.2K) [image/jpeg]
# Saving to: ‘241048.jpg’
#
# 241048.jpg          100%[===================>]   3.22K  --.-KB/s    in 0s
#
# 2025-04-21 17:25:27 (984 MB/s) - ‘241048.jpg’ saved [3299/3299]

# %%
img= imread('img_chica.jpg')
plt.imshow(img)
plt.show()

# %%
img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img.shape
# Out:
# (656, 1250, 3)

# %%
#la imagen tiene 656 pixeles de alto y 1250 px de ancho

# %%
#voy a achicar un poco la imagen teniendo en cuenta estos valores
img_resize=cv2.resize(img, (400,500))
plt.imshow(img_resize)
#con ese tamaño sigo logrando ver la imagen y de hecho se genera un lindo efecto visual

# %%
#voy a probar agrandar la imagen
img_big = cv2.resize(img, (1700, 1100), interpolation=cv2.INTER_CUBIC)
plt.imshow(img_big)
#IMPORTANTE, al hacer el resize el primer valor es el ancho y el segundo valor el alto, es decir, se invierten
